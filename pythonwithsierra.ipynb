# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\JvonTech'

# %%
pd.read_csv('C:\\Users\\JvonTech\\Downloads\\MOCK_DATA.csv')
# Out:
#        id   first_name     last_name                              email  \
# 0       1        Nerte         Frise                  nfrise0@about.com
# 1       2        Karon     Courtonne              kcourtonne1@unblog.fr
# 2       3        Alana      Oakshott          aoakshott2@whitehouse.gov
# 3       4      Beverie     Heinemann             bheinemann3@disqus.com
# 4       5     Nicolina         Cruft                  ncruft4@issuu.com
# 5       6      Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6       7       Hailey         Zoppo                   hzoppo6@ning.com
# 7       8       Sloane      Minchell               sminchell7@google.nl
# 8       9       Inessa        Pitway            ipitway8@vistaprint.com
# 9      10         Edan        Wadham                   ewadham9@icq.com
# 10     11       Violet         Heart              vhearta@delicious.com
# 11     12         Rock         Autie                   rautieb@java.com
# ...

# %%
os.path.join(os.getcwd(),'Downloads\\MOCK_DATA.csv')
# Out:
# 'C:\\Users\\JvonTech\\Downloads\\MOCK_DATA.csv'

# %%
pd.read_csv(os.path.join(os.getcwd(),'Downloads\\MOCK_DATA.csv'))
# Out:
#        id   first_name     last_name                              email  \
# 0       1        Nerte         Frise                  nfrise0@about.com
# 1       2        Karon     Courtonne              kcourtonne1@unblog.fr
# 2       3        Alana      Oakshott          aoakshott2@whitehouse.gov
# 3       4      Beverie     Heinemann             bheinemann3@disqus.com
# 4       5     Nicolina         Cruft                  ncruft4@issuu.com
# 5       6      Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6       7       Hailey         Zoppo                   hzoppo6@ning.com
# 7       8       Sloane      Minchell               sminchell7@google.nl
# 8       9       Inessa        Pitway            ipitway8@vistaprint.com
# 9      10         Edan        Wadham                   ewadham9@icq.com
# 10     11       Violet         Heart              vhearta@delicious.com
# 11     12         Rock         Autie                   rautieb@java.com
# ...

# %%
#testingvariables with code above lol

# %%
Bob = os.getcwd()

# %%
os.path.join(Bob,'Downloads\\MOCK_DATA.csv')
# Out:
# 'C:\\Users\\JvonTech\\Downloads\\MOCK_DATA.csv'

# %%
Rob=os.path.join(Bob,'Downloads\\MOCK_DATA.csv')

# %%
pd.read_csv(Rob)
# Out:
#        id   first_name     last_name                              email  \
# 0       1        Nerte         Frise                  nfrise0@about.com
# 1       2        Karon     Courtonne              kcourtonne1@unblog.fr
# 2       3        Alana      Oakshott          aoakshott2@whitehouse.gov
# 3       4      Beverie     Heinemann             bheinemann3@disqus.com
# 4       5     Nicolina         Cruft                  ncruft4@issuu.com
# 5       6      Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6       7       Hailey         Zoppo                   hzoppo6@ning.com
# 7       8       Sloane      Minchell               sminchell7@google.nl
# 8       9       Inessa        Pitway            ipitway8@vistaprint.com
# 9      10         Edan        Wadham                   ewadham9@icq.com
# 10     11       Violet         Heart              vhearta@delicious.com
# 11     12         Rock         Autie                   rautieb@java.com
# ...

# %%
Jen = pd.read_csv(Rob)

# %%
print(Jen)
# Out:
#        id   first_name     last_name                              email  \
# 0       1        Nerte         Frise                  nfrise0@about.com
# 1       2        Karon     Courtonne              kcourtonne1@unblog.fr
# 2       3        Alana      Oakshott          aoakshott2@whitehouse.gov
# 3       4      Beverie     Heinemann             bheinemann3@disqus.com
# 4       5     Nicolina         Cruft                  ncruft4@issuu.com
# 5       6      Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6       7       Hailey         Zoppo                   hzoppo6@ning.com
# 7       8       Sloane      Minchell               sminchell7@google.nl
# 8       9       Inessa        Pitway            ipitway8@vistaprint.com
# 9      10         Edan        Wadham                   ewadham9@icq.com
# 10     11       Violet         Heart              vhearta@delicious.com
# 11     12         Rock         Autie                   rautieb@java.com
# ...

# %%
type(Jen)
# Out:
# pandas.core.frame.DataFrame

# %%
Jen["email"]
# Out:
# 0                      nfrise0@about.com
# 1                  kcourtonne1@unblog.fr
# 2              aoakshott2@whitehouse.gov
# 3                 bheinemann3@disqus.com
# 4                      ncruft4@issuu.com
# 5      rvedeneev5@networkadvertising.org
# 6                       hzoppo6@ning.com
# 7                   sminchell7@google.nl
# 8                ipitway8@vistaprint.com
# 9                       ewadham9@icq.com
# 10                 vhearta@delicious.com
# 11                      rautieb@java.com
# 12                linnocentc@sina.com.cn
# 13                 sringsd@google.com.hk
# 14       heldredgee@pagesperso-orange.fr
# 15                dchadburnf@cornell.edu
# 16             psteablerg@techcrunch.com
# 17              drofeh@sciencedirect.com
# 18                 msomersi@sakura.ne.jp
# 19                kkinnardj@virginia.edu
# 20              wwarrenk@studiopress.com
# 21              mtoffell@bizjournals.com
# 22                   ahockellm@nymag.com
# ...

# %%
Jen["ip_address"]
# Out:
# 0         253.18.56.38
# 1      146.252.152.212
# 2        236.34.207.35
# 3        170.253.78.76
# 4         35.83.90.164
# 5        211.10.109.12
# 6        209.230.40.62
# 7        178.25.40.191
# 8       228.22.112.209
# 9       195.169.53.128
# 10     117.164.198.223
# 11      166.224.58.144
# 12       247.45.206.78
# 13      54.123.119.240
# 14      248.132.105.76
# 15     147.127.190.132
# 16        59.185.69.53
# 17      132.179.107.36
# 18      122.56.236.186
# 19      242.42.147.238
# 20        193.13.69.72
# 21        89.46.199.48
# 22        89.12.70.254
# 23      217.27.197.122
# 24      151.38.251.140
# 25        57.10.121.56
# 26       250.2.163.113
# 27       124.254.9.227
# 28       60.93.239.230
# 29       190.6.226.225
#             ...
# 970      178.142.44.20
# 971     166.109.197.22
# 972      102.70.232.14
# 973        101.52.61.4
# 974     200.215.220.63
# 975       134.11.202.9
# 976       196.2.105.10
# 977       133.27.16.10
# 978    173.132.125.250
# ...

# %%
Jen['ip_address,email']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ip_address,email'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-71777fc49d3b> in <module>
# ----> 1 Jen['ip_address,email']
#
# ...

# %%
Jen[["ip_address","email"]]
# Out:
#           ip_address                              email
# 0       253.18.56.38                  nfrise0@about.com
# 1    146.252.152.212              kcourtonne1@unblog.fr
# 2      236.34.207.35          aoakshott2@whitehouse.gov
# 3      170.253.78.76             bheinemann3@disqus.com
# 4       35.83.90.164                  ncruft4@issuu.com
# 5      211.10.109.12  rvedeneev5@networkadvertising.org
# 6      209.230.40.62                   hzoppo6@ning.com
# 7      178.25.40.191               sminchell7@google.nl
# 8     228.22.112.209            ipitway8@vistaprint.com
# 9     195.169.53.128                   ewadham9@icq.com
# 10   117.164.198.223              vhearta@delicious.com
# 11    166.224.58.144                   rautieb@java.com
# 12     247.45.206.78             linnocentc@sina.com.cn
# 13    54.123.119.240              sringsd@google.com.hk
# 14    248.132.105.76    heldredgee@pagesperso-orange.fr
# 15   147.127.190.132             dchadburnf@cornell.edu
# ...

# %%
Jen[Jen.columns[1:4]]
# Out:
#       first_name     last_name                              email
# 0          Nerte         Frise                  nfrise0@about.com
# 1          Karon     Courtonne              kcourtonne1@unblog.fr
# 2          Alana      Oakshott          aoakshott2@whitehouse.gov
# 3        Beverie     Heinemann             bheinemann3@disqus.com
# 4       Nicolina         Cruft                  ncruft4@issuu.com
# 5        Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6         Hailey         Zoppo                   hzoppo6@ning.com
# 7         Sloane      Minchell               sminchell7@google.nl
# 8         Inessa        Pitway            ipitway8@vistaprint.com
# 9           Edan        Wadham                   ewadham9@icq.com
# 10        Violet         Heart              vhearta@delicious.com
# 11          Rock         Autie                   rautieb@java.com
# 12        Lesley      Innocent             linnocentc@sina.com.cn
# ...

# %%
Jen['email'][10]
# Out:
# 'vhearta@delicious.com'

# %%
templist = []

# %%
Bob =[]

# %%
templist
# Out:
# []

# %%
type(templist)
# Out:
# list

# %%
for typethis in range(len(Jen)):
    if typethis <= 8: 
        print(Jen['email'][typethis])
        templist.append(Jen['email'][typethis])
    elif typethis <= 8:
        Bob.append(Jen['email'][typethis])
# Out:
# nfrise0@about.com
# kcourtonne1@unblog.fr
# aoakshott2@whitehouse.gov
# bheinemann3@disqus.com
# ncruft4@issuu.com
# rvedeneev5@networkadvertising.org
# hzoppo6@ning.com
# sminchell7@google.nl
# ipitway8@vistaprint.com

# %%
if 3 ==  [1:9]
# Out:
#   File "<ipython-input-31-abc6bd9603ef>", line 1
#     if 3 ==  [1:9]
#                ^
# SyntaxError: invalid syntax

# %%
range(len(Jen))
# Out:
# range(0, 1000)

# %%
Bob
# Out:
# []

# %%
templist
# Out:
# ['nfrise0@about.com',
#  'kcourtonne1@unblog.fr',
#  'aoakshott2@whitehouse.gov',
#  'bheinemann3@disqus.com',
#  'ncruft4@issuu.com',
#  'rvedeneev5@networkadvertising.org',
#  'hzoppo6@ning.com',
#  'sminchell7@google.nl',
#  'ipitway8@vistaprint.com']

# %%
for typethis in range(len(Jen)):
    if typethis <= 8: 
        print(Jen['email'][typethis])
        templist.append(Jen['email'][typethis])
    if typethis <= 8:
        Bob.append(Jen['ip_address'][typethis])
        print(Jen['ip_address'][typethis])
# Out:
# nfrise0@about.com
# 253.18.56.38
# kcourtonne1@unblog.fr
# 146.252.152.212
# aoakshott2@whitehouse.gov
# 236.34.207.35
# bheinemann3@disqus.com
# 170.253.78.76
# ncruft4@issuu.com
# 35.83.90.164
# rvedeneev5@networkadvertising.org
# 211.10.109.12
# hzoppo6@ning.com
# 209.230.40.62
# sminchell7@google.nl
# 178.25.40.191
# ipitway8@vistaprint.com
# 228.22.112.209

# %%
# break and continued statements

# %%
for i in range(len(Jen)):
    if i == 5 :
        break    
    print("broken loop") 
 #basically, anything  under If is in one statement but anything tabbed out is a new statement
# Out:
# broken loop
# broken loop
# broken loop
# broken loop
# broken loop

# %%
for typethis in range(len(Jen)):
    if Jen['ip_address'][typethis].isnull() == True: # .isnull doesn't work for strings, use instead np.where
        continue  #continue basicallys says if a certain condition is met ignore it and continue the loop.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-e6ebc0acc9c9> in <module>
#       1 for typethis in range(len(Jen)):
# ----> 2     if Jen['ip_address'][typethis].isnull() == True: # .isnull doesn't work for strings, use instead np.where
#       3         continue  #continue basicallys says if a certain condition is met ignore it and continue the loop.
#       4
#
# AttributeError: 'str' object has no attribute 'isnull'

# %%
Jen
# Out:
#        id   first_name     last_name                              email  \
# 0       1        Nerte         Frise                  nfrise0@about.com
# 1       2        Karon     Courtonne              kcourtonne1@unblog.fr
# 2       3        Alana      Oakshott          aoakshott2@whitehouse.gov
# 3       4      Beverie     Heinemann             bheinemann3@disqus.com
# 4       5     Nicolina         Cruft                  ncruft4@issuu.com
# 5       6      Ritchie      Vedeneev  rvedeneev5@networkadvertising.org
# 6       7       Hailey         Zoppo                   hzoppo6@ning.com
# 7       8       Sloane      Minchell               sminchell7@google.nl
# 8       9       Inessa        Pitway            ipitway8@vistaprint.com
# 9      10         Edan        Wadham                   ewadham9@icq.com
# 10     11       Violet         Heart              vhearta@delicious.com
# 11     12         Rock         Autie                   rautieb@java.com
# ...

# %%
Jen['gender'][0:9]
# Out:
# 0    Female
# 1    Female
# 2    Female
# 3    Female
# 4    Female
# 5      Male
# 6      Male
# 7      Male
# 8    Female
# Name: gender, dtype: object

# %%
i = 0  #set to zero to start the count at 0.
while i < 10:
    print(Jen['gender'][i]) #basically print to the gender column
    i = i + 1 #stops the counter from going on and on by setting it equal to it's self
# Out:
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# Female
# ...

# %%
i = 0
while i < 10:
#     print(i)
    if (Jen['gender'][i]) == 'Female': #becareful of capitailization of words/spelling
        #print(i)
        print(Jen['gender'][i])
    i = i  + 1  #Basically don't leave this statement under print because it won't allow code to run 10 numbers, cause it will get stuck when it's not female.
# Out:
# Female
# Female
# Female
# Female
# Female
# Female

# %%
Jen['gender'][0]
# Out:
# 'Female'

# %%
#Today we worked on adding stuff to my github
